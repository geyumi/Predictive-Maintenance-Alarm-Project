# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.cluster import KMeans
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import os

# Mount Google Drive
drive.mount('/content/drive')

# Path of folder
folder_path = '/content/drive/MyDrive/Colab Notebooks/2024_08_01 for all sites kmeans site id wise last 3 months /'

# Get list of all CSV files in the folder
csv_files = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.csv')]

# Initialize an empty list to hold the dataframes
dfs = []

# Loop through the CSV files and read each one into a dataframe
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)
# Out:
# Mounted at /content/drive
# <ipython-input-1-02eea4cc2222>:28: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %%
# Concatenate all dataframes into a single dataframe
data = pd.concat(dfs, ignore_index=True)

# Sort by 'First Occurred On' in descending order (latest alarms first)
df = data.sort_values(by='First Occurred On', ascending=False)

# Convert 'First Occurred On' to datetime, handle errors and fill NaT with a default date
df['First Occurred On'] = pd.to_datetime(df['First Occurred On'], errors='coerce')

# %%
# Reference time
reference_time = pd.to_datetime('2024-08-01 22:00:00')

# Calculate the relative day index, handle NaT by filling with a large negative number
df['Relative Day Index'] = ((df['First Occurred On'] - reference_time).dt.total_seconds() // 86400).fillna(-9999).astype(int)

# Adjust the index to set the 08:00 to 08:00 of the next day as 0, and previous days as -1, -2, -3, etc.
df['Relative Day Index'] = df['Relative Day Index'].apply(lambda x: x if x < 0 else x)

# Print the updated dataframe
df.head(50000)
# Out:
#             Last Occurred On                   Alarm Source Alarm Severity  \
# 3864384  2024-08-01 23:03:12               Badulla-BD0001-L          Major
# 3864385  2024-08-01 23:02:44  MC1_Mundal_South-PU0271-BDGHP       Critical
# 3864386  2024-08-01 23:02:36                         vUSN02          Major
# 3864387  2024-08-01 23:02:30                    PILI-AMF-01          Major
# 3864388  2024-08-01 23:02:27                    PILI_VUSN01          Major
# ...                      ...                            ...            ...
# 47722    2024-07-31 12:06:24                       U2020ACC          Major
# 47723    2024-07-31 12:06:23                       U2020ACC          Major
# 47724    2024-07-31 12:06:21                    PILI-AMF-01          Major
# 47725    2024-07-31 12:06:17                    PILI_VUSN01          Major
# 47726    2024-07-31 12:06:17                      KALA_SGSN          Major
#
#                                 Alarm Name Alarm ID  \
# 3864384                   User Plane Fault    25954
# 3864385       Battery Deep Discharge Alarm    65089
# 3864386                     S1ap Link Down    80589
# 3864387                     S1ap Link Down    80589
# 3864388                     S1ap Link Down    80589
# ...                                    ...      ...
# 47722    Parallel Alarm Exceeds the Limit       832
# 47723    Parallel Alarm Exceeds the Limit       832
# 47724                       S1ap Link Down    80589
# 47725                       S1ap Link Down    80589
# 47726                       S1ap Link Down    14001
#
#                                        Alarm Location Info     Site Name  \
# 3864384                                    Service Type=X2       Badulla
# 3864385  Cabinet No.=0, Subrack No.=0, Slot No.=19, Por...  Mundal_South
# 3864386  Mobile Country Code=413, Mobile Network Code=0...           NaN
# 3864387  Service Instance=LINK_VNFC_999, Mobile Country...   Piliyandala
# 3864388  Mobile Country Code=413, Mobile Network Code=0...           NaN
# ...                                                    ...           ...
# 47722    RuleID=1984, Source Alarm Information="Alarm N...           NaN
# 47723    RuleID=1980, Source Alarm Information="Alarm N...           NaN
# 47724    Service Instance=LINK_VNFC_999, Mobile Country...   Piliyandala
# 47725    Mobile Country Code=413, Mobile Network Code=0...           NaN
# 47726    SubrackNo=5, SlotNo=3, ProcType=SGP, ProcNo=6,...         Dummy
#
#                   Cleared On   First Occurred On Clearance Status Ticket ID  \
# 3864384                  NaN 2024-08-01 23:03:12        Uncleared       NaN
# 3864385                  NaN 2024-08-01 23:02:44        Uncleared       NaN
# 3864386  2024-08-01 23:08:50 2024-08-01 23:02:36          Cleared       NaN
# 3864387  2024-08-01 23:08:54 2024-08-01 23:02:30          Cleared       NaN
# 3864388  2024-08-01 23:08:51 2024-08-01 23:02:27          Cleared       NaN
# ...                      ...                 ...              ...       ...
# 47722    2024-07-31 12:50:25 2024-07-31 12:06:24          Cleared       NaN
# 47723    2024-07-31 12:50:25 2024-07-31 12:06:23          Cleared       NaN
# 47724    2024-07-31 17:10:15 2024-07-31 12:06:21          Cleared       NaN
# 47725    2024-07-31 17:10:15 2024-07-31 12:06:17          Cleared       NaN
# 47726    2024-07-31 17:09:54 2024-07-31 12:06:17          Cleared       NaN
#
#         Site ID  Vendor  Domain Device Type  Relative Day Index Cluster
# 3864384  BD0001  HUAWEI  Access      eNodeB                   0     NaN
# 3864385  PU0271  HUAWEI   Power        GBTS                   0     NaN
# 3864386     NaN  HUAWEI  Others         NaN                   0     NaN
# 3864387  CM0091  HUAWEI  Others         UNC                   0     NaN
# 3864388     NaN  HUAWEI  Others         NaN                   0     NaN
# ...         ...     ...     ...         ...                 ...     ...
# 47722       NaN  HUAWEI  Others         NaN                  -2     NaN
# 47723       NaN  HUAWEI  Others         NaN                  -2     NaN
# 47724    CM0091  HUAWEI  Others         UNC                  -2     NaN
# 47725       NaN  HUAWEI  Others         NaN                  -2     NaN
# 47726    VV0000  HUAWEI    Core        SGSN                  -2     NaN
#
# [50000 rows x 17 columns]

# %%
# Filter the data for HUAWEI and Access domain
filtered_data = df[(df['Vendor'] == 'HUAWEI')]

# Retain only the specified columns
columns_to_keep = ['Site ID', 'Alarm Name', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index']
df_filtered = filtered_data[columns_to_keep]

# Identify the five most recent Site IDs
recent_site_ids = df_filtered['Site ID'].value_counts().index[:5]

# Filter the dataframe to include only the most recent Site IDs
df_filtered = df_filtered[df_filtered['Site ID'].isin(recent_site_ids)]

# Encode categorical columns except 'Relative Day Index'
categorical_columns = df_filtered.select_dtypes(include=['object']).columns
label_encoders = {}
for column in categorical_columns:
    le = LabelEncoder()
    df_filtered[column] = le.fit_transform(df_filtered[column].astype(str))
    label_encoders[column] = le

# Print the updated dataframe
df_filtered.head(100)
# Out:
#          Site ID  Alarm Name  Vendor  Domain  Device Type  Relative Day Index
# 3864387        0         459       0       4           18                   0
# 3864391        4         229       0       2           10                   0
# 3864397        4         230       0       2           22                   0
# 3864406        0         459       0       4           18                   0
# 3864414        1         248       0       4            6                   0
# ...          ...         ...     ...     ...          ...                 ...
# 276            0         459       0       4           18                   0
# 282            4         459       0       2           13                   0
# 280            4         459       0       2           13                   0
# 279            4         459       0       2           13                   0
# 278            4         459       0       2           13                   0
#
# [100 rows x 6 columns]

# %%
# Clustering to find common patterns
# Determine the optimal number of clusters using the elbow method
# wcss = []
# for i in range(1, 11):
#     kmeans = KMeans(n_clusters=i, random_state=42)
#     kmeans.fit(df_filtered)
#     wcss.append(kmeans.inertia_)

# plt.plot(range(1, 11), wcss)
# plt.title('Elbow Method for Optimal k')
# plt.xlabel('Number of clusters')
# plt.ylabel('WCSS')
# plt.show()

# Fit the KMeans model with the optimal number of clusters
optimal_clusters =20   # Increased number of clusters
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
df_filtered['Cluster'] = kmeans.fit_predict(df_filtered[['Alarm Name', 'Site ID']])

# Analyze the clusters
print(df_filtered.groupby('Cluster').mean())
print(df_filtered.groupby('Cluster').size())

# Print cluster details and alarm patterns
cluster_patterns = {}
for cluster in range(optimal_clusters):
    print(f"Cluster {cluster} details:")
    cluster_data = df_filtered[df_filtered['Cluster'] == cluster]
    alarm_patterns = cluster_data.groupby(['Alarm Name', 'Site ID']).size()
    cluster_patterns[cluster] = alarm_patterns
    print("Alarm Patterns:")
    print(alarm_patterns)
    print("\n")

# Plot the clusters
# sns.pairplot(df_filtered, hue='Cluster')
# plt.show()

# Inverse transform the scaled columns for interpretation
# scaler = MinMaxScaler()
# df_filtered[['Alarm Name', 'Site ID', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index', 'Cluster']] = scaler.inverse_transform(df_filtered[['Alarm Name', 'Site ID', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index', 'Cluster']])

# Convert back to original categorical values using label_encoders
# for column in label_encoders.keys():
#     df_filtered[column] = label_encoders[column].inverse_transform(df_filtered[column].round().astype(int))

# Display sample output of clustered data
df_filtered.head(100)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#           Site ID  Alarm Name  Vendor    Domain  Device Type  \
# Cluster
# 0        0.632023  302.737261     0.0  2.216414    13.934457
# 1        3.999979  459.036460     0.0  1.999773    17.134283
# 2        2.072113   65.470249     0.0  2.843426    20.621075
# 3        1.414391  144.324210     0.0  2.131540    13.791392
# 4        3.864954  229.053326     0.0  2.044976    21.667415
# 5        0.718422  328.108389     0.0  2.231597    13.934354
# 6        2.764519  401.357622     0.0  1.727477     9.228366
# 7        1.886066  555.379271     0.0  2.448622    18.428934
# 8        1.440680   10.896672     0.0  2.097048    25.311085
# 9        1.041934   95.783265     0.0  2.766738    24.953011
# 10       0.807489   33.538015     0.0  2.811897    24.582460
# 11       3.919869  496.867354     0.0  1.886593    10.522714
# 12       2.941496  249.013424     0.0  2.111629    10.673680
# 13       1.580387  365.819244     0.0  2.068728    10.031312
# 14       2.170937  186.494190     0.0  2.030239    10.920342
# 15       3.733072  122.105339     0.0  2.008908    19.089267
# 16       3.155281  427.247044     0.0  1.657207    22.261842
# 17       3.990313  470.361187     0.0  1.152622    11.698811
# 18       1.542463  271.617420     0.0  2.529196    21.800765
# 19       0.087154  458.056035     0.0  2.372913    17.191906
#
#          Relative Day Index
# Cluster
# 0                -48.752790
# 1                -55.862484
# 2                -31.597276
# 3                -58.177673
# 4                -51.853365
# 5                -47.586791
# 6                -47.636105
# 7                -46.540201
# 8                -53.632392
# 9                -47.827792
# 10               -39.235816
# 11               -53.761081
# 12               -56.963679
# 13               -71.710816
# 14               -41.177376
# 15               -47.520962
# 16               -51.537739
# 17               -51.454845
# 18               -36.901132
# 19               -47.009570
# Cluster
# 0     342644
# 1     291056
# 2      83494
# 3      14870
# 4      67303
# 5     229109
# 6      32045
# 7       7873
# 8      21814
# 9      15429
# 10     19282
# 11     21727
# 12     21007
# 13     22771
# 14      7143
# 15     32106
# 16     14799
# 17     36751
# 18     13341
# 19    299689
# dtype: int64
# Cluster 0 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 288         0              1
#             1              1
# 289         0              2
# 290         4             24
# 291         4              6
# 292         3              3
# 293         0             24
#             1             24
# 294         0             17
#             1             16
# 295         4              5
# 296         4              3
# 297         4              5
# 298         0          43856
#             1          43866
# 299         4             10
# 300         4             28
# 301         0           4668
#             1           5158
# 302         0          25614
#             1          24445
#             4             16
# 303         1             39
# 304         0          43854
#             1          43864
# 305         0          43860
#             1          43873
#             4             10
# 306         4            528
# 307         0           3018
#             1           3500
# 308         4            469
# 309         4             96
# 310         4           1906
# 311         4            135
# 312         4             40
# 313         4           2319
# 314         4             67
# 315         4           7274
# dtype: int64
#
#
# Cluster 1 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 451         4              26
# 452         4              33
# 457         4              30
# 458         4              37
# 459         4          287859
# 460         4              10
# 461         4             787
# 462         4             902
# 463         1               2
# 464         4            1370
# dtype: int64
#
#
# Cluster 2 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 50          4              1
# 51          4              6
# 52          2              4
#             3             30
# 53          2              1
# 54          0              3
#             4              3
# 55          4             17
# 56          2              3
# 57          4             96
# 58          4            141
# 59          4            821
# 60          4          24906
# 61          4            747
# 62          4            330
# 63          0             33
#             1             74
# 64          4           1610
# 65          4              2
# 66          0             30
# 67          0              1
# 68          1          53362
# 69          4              1
# 70          4              9
# 71          2              3
#             3              9
#             4             89
# 72          4              4
# 73          0              1
#             1              1
# 74          0              9
#             1              1
# 75          4             15
# 76          4            155
# 77          4              4
# 78          0              2
#             3            112
#             4             16
# 79          1              1
#             2             37
# 80          2             16
#             3             55
#             4            733
# dtype: int64
#
#
# Cluster 3 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 134         0            49
#             4            70
# 135         4           198
# 136         0           524
#             1           516
# 137         0            34
#             4           118
# 138         4           730
# 139         0          2399
#             1          2652
# 140         0           405
#             1           429
# 141         0           402
#             1           469
# 142         0           405
#             1           429
# 143         0           404
#             1           469
# 144         4             6
# 145         4            51
# 146         4             2
# 147         0            14
# 148         0           207
#             1           219
# 149         0            23
# 150         0            81
#             1            69
# 151         4             1
# 152         4             8
# 153         1             2
# 154         0             1
#             1             1
# 155         1             3
# 156         4             2
# 157         0             1
#             1             2
# 158         4          2549
# 159         0             3
#             1            97
# 160         2             3
#             4            10
# 161         4            26
# 162         0           367
#             1           274
# 163         0            33
#             1            46
# 164         1             1
# 165         4            66
# dtype: int64
#
#
# Cluster 4 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 208         1             17
# 209         0              1
#             1              1
# 210         1              1
# 211         1            206
# 212         0             24
#             1             49
# 213         0             80
#             1            323
# 214         1              9
# 215         1            461
# 216         1              1
# 217         1             18
# 218         1              6
# 219         4              2
# 220         1              2
#             4             55
# 221         1              3
# 222         4             13
# 223         4           4051
# 224         0              2
#             4              6
# 225         0           1292
#             4           1340
# 226         1             25
#             2              4
#             3              3
#             4             41
# 227         4            397
# 228         4             52
# 229         4            138
# 230         4          58622
# 231         0             18
# 232         0             10
# 233         4              8
# 234         4              3
# 235         4             10
# 236         0              1
# 237         4              2
# 238         4              5
# 239         4              1
# dtype: int64
#
#
# Cluster 5 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 316         4           7866
# 317         4              1
# 318         0             42
#             1             52
# 319         1              5
# 320         1              8
# 321         4              8
# 322         4              4
# 323         4              3
# 324         0              1
#             1             11
# 325         0          38285
#             1            945
# 326         0             40
#             1             24
# 327         0              4
#             1              3
# 328         0          38580
#             1          41734
# 329         0          44376
#             1          44378
# 330         4            362
# 331         4              9
# 332         4            178
# 333         2             10
#             3             59
#             4              1
# 334         4              2
# 335         0             26
#             1              1
#             4              4
# 336         1             44
# 337         1              2
# 338         0            278
# 339         0            162
#             1            819
#             4           3798
# 340         0             48
# 341         4           6512
# 342         4             19
# 343         0             13
#             1             18
#             2             32
#             3             18
#             4            222
# 344         4             69
# 345         0              1
#             2              1
#             4              1
# 346         0             30
# dtype: int64
#
#
# Cluster 6 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 384         0              4
#             4             10
# 385         4              3
# 386         4             53
# 387         0              5
#             4              1
# 388         1             24
# 389         0              1
# 390         4              2
# 391         1              1
# 392         1             29
# 393         0              7
#             1             22
# 394         4           1271
# 395         4              6
# 396         4             25
# 397         0              9
#             1              8
# 398         4          13425
# 399         4             13
# 400         4            102
# 401         4              2
# 402         1              6
# 403         0           2768
#             1           3093
# 404         0           1741
#             1           1912
#             4           1254
# 405         0            420
#             1            574
#             4            231
# 406         0            194
#             1            317
#             4             22
# 407         0              4
#             4           3737
# 408         4            439
# 409         4             17
# 410         0              2
# 411         1             11
# 412         0            189
# 413         0             56
# 414         4             35
# dtype: int64
#
#
# Cluster 7 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 527         0             2
#             1             3
#             4            43
# 528         1             1
#             4            12
#                        ...
# 579         4          1208
# 580         0            28
#             1           142
# 581         0             1
# 582         4             1
# Length: 74, dtype: int64
#
#
# Cluster 8 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 0           1             11
# 1           1              1
# 2           1              1
# 3           1              2
# 4           2          10294
# 5           4              3
# 6           0             11
# 7           4              2
# 8           0              4
#             1              1
# 9           4             19
# 10          4              4
# 11          1              2
# 12          1              1
#             4             13
# 13          4             22
# 14          0             63
# 15          4            142
# 16          4             13
# 17          0            669
#             1           9258
# 18          0            336
#             1            301
# 19          0            333
#             1            262
# 20          4             28
# 21          0             13
# 22          3              5
# dtype: int64
#
#
# Cluster 9 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 81          0             1
#             1            18
#             2            62
#             3           112
#             4           208
# 82          1            46
# 83          4            30
# 84          4            60
# 85          0          1479
#             1            47
# 86          1             2
# 87          4             5
# 88          0             2
# 89          4          2841
# 90          4             4
# 91          4             2
# 92          0             3
#             1             4
#             4            62
# 93          0            13
#             1            26
#             4            54
# 94          0            20
#             1            12
# 95          4             6
# 96          1             2
#             4            63
# 97          4            11
# 98          4             1
# 99          0           520
#             1           154
# 100         0          7698
#             1          1296
# 101         4             4
# 102         0           201
#             1           275
# 103         4             1
# 104         4             8
# 105         1             3
#             3             1
# 106         4             8
# 107         4             4
# 108         4            60
# dtype: int64
#
#
# Cluster 10 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 23          0             69
# 24          0            213
#             1            126
# 25          1             93
# 26          0             20
# 27          4             16
# 28          4              2
# 29          3              1
# 30          1              2
#             2            125
# 31          0             48
#             1             27
#             4             40
# 32          0          13730
# 33          0             29
#             1             76
# 34          0             62
#             1             44
#             4             32
# 35          0            334
#             1            704
# 36          4              6
# 37          0              8
# 38          4           1565
# 39          4              7
# 40          4            272
# 41          4              1
# 42          4            848
# 43          4              1
# 44          4            240
# 45          4              1
# 46          4            474
# 47          3             39
#             4              1
# 48          4             25
# 49          4              1
# dtype: int64
#
#
# Cluster 11 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 484         0             13
#             1              9
# 485         1              4
#             4              8
# 486         0             12
#             1            153
# 487         4              2
# 488         0             10
# 489         4             16
# 490         4              1
# 491         0             22
# 492         1             11
# 493         4             29
# 494         4            104
# 495         4          17599
# 496         0             47
# 497         4            174
# 498         4             32
# 499         1              1
# 500         4              9
# 501         4              5
# 502         0              5
# 503         0              4
# 504         4           2439
# 505         4             24
# 506         1              2
# 507         4              1
# 508         0              1
# 509         4             23
# 510         0              1
# 511         0             17
#             4            217
# 512         2             37
#             3             81
# 513         0              1
# 514         0             59
#             1             67
# 515         4            179
# 516         4             17
# 517         3              1
# 518         4              4
# 519         4            113
# 520         1              7
# 521         4              8
# 522         0              4
#             1              4
#             4             60
# 523         4             82
# 524         0              2
#             1              2
# 525         1              3
# 526         0              1
# dtype: int64
#
#
# Cluster 12 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 240         0              1
# 241         1              9
#             4             31
# 242         1              8
#             4             85
# 243         4            372
# 244         4              9
# 245         4              4
# 246         1           3196
# 247         1           3216
# 248         1            143
# 249         1            149
# 250         0             30
#             1             28
#             4          12055
# 251         0             92
#             4            676
# 252         0             57
#             1             12
#             4             72
# 253         0              1
# 254         1              1
#             4              2
# 255         0            126
#             1             46
# 256         0              9
#             1            124
# 257         0             43
#             4            392
# 258         0              1
# 259         4             12
# 260         4              5
# dtype: int64
#
#
# Cluster 13 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 347         0              1
# 348         0              1
# 349         4              7
# 350         0              2
# 351         0              1
# 352         4             30
# 353         0              2
#             4              7
# 354         0             13
# 355         1             21
# 356         0             16
# 357         0            666
#             4             45
# 358         2              1
# 359         4             13
# 360         0            470
#             4            826
# 361         0             30
#             4              2
# 362         0              4
# 363         4            306
# 364         1             58
# 365         1          15043
# 366         1            151
# 367         4           2963
# 368         0             10
# 369         4              4
# 370         4              2
# 371         0              2
# 372         4              4
# 373         4             41
# 374         4            670
# 375         2              3
#             4             10
# 376         4              1
# 377         4              4
# 378         0             52
# 379         0             32
#             1            585
# 380         0            287
# 381         4              4
# 382         0             16
#             1            341
# 383         1             24
# dtype: int64
#
#
# Cluster 14 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 166         2             1
#             4            27
# 167         4           258
# 168         4            17
# 169         4             1
# 170         0             2
# 171         0             2
# 172         1             2
# 173         1             5
# 174         4            58
# 175         4             1
# 176         4            35
# 177         0           143
#             1            94
# 178         1             3
# 179         4           624
# 180         0             1
#             1             3
# 181         0           122
#             1            92
# 182         1           158
# 183         1          3485
# 184         4             3
# 185         4             1
# 186         1             4
# 187         4            68
# 188         4             2
# 189         4             2
# 190         2             2
#             3            16
# 191         4            23
# 192         4            11
# 193         4           392
# 194         1             4
#             3             1
# 195         3             1
#             4             2
# 196         4            11
# 197         0            41
# 198         0            20
#             4             4
# 199         4            58
# 200         3             5
# 201         4             1
# 202         4           132
# 203         4           259
# 204         4           135
# 205         0             1
#             4           766
# 206         0            16
#             1            16
# 207         0            10
#             1             2
# dtype: int64
#
#
# Cluster 15 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 109         4              3
# 110         1             14
# 111         1             13
# 112         0            145
#             1            335
# 113         1              8
# 114         0             28
# 115         1              1
# 116         0              1
# 117         0             21
#             1             54
# 118         0             24
#             4             36
# 119         0             21
#             1            173
# 120         4             56
# 121         4              6
# 122         0            385
#             1            387
#             4          20898
# 123         0            440
#             1            413
#             4           8525
# 124         4              4
# 125         0              3
#             1             10
# 126         0              3
#             1              3
# 127         4             11
# 128         1             12
#             4             12
# 129         4             16
# 130         4             25
# 131         0              2
#             1              1
#             4              3
# 132         4             12
# 133         1              2
# dtype: int64
#
#
# Cluster 16 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 415         0             1
# 416         4            84
# 417         4            12
# 418         4             8
# 419         0           252
#             1           142
# 420         1             1
# 421         1             2
# 422         0             5
#             1             2
# 423         1             2
# 424         0             7
#             4           138
# 425         0             1
#             4            17
# 426         4          8593
# 427         2          3646
# 428         2            30
# 429         2           180
# 430         2            75
#             3             2
#             4             1
# 431         1             5
#             2             3
# 432         1             6
#             2           415
#             3             4
#             4             1
# 433         2             1
#             3             2
# 434         2             1
# 435         4             7
# 436         2            21
# 437         2           188
# 438         2            23
# 439         2           250
# 440         2           570
# 441         1             1
#             2            51
# 442         0             8
#             1             2
#             4            39
# dtype: int64
#
#
# Cluster 17 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 465         4            958
# 466         0             10
#             1              7
# 467         4              2
# 468         0             59
#             1              1
# 469         1              1
#             3              7
#             4           8375
# 470         2              9
#             3              4
#             4          22696
# 471         4             30
# 472         4              1
# 473         4            643
# 474         4            232
# 475         4           1379
# 476         4            186
# 477         4           1966
# 478         4             12
# 479         0              4
#             4              8
# 480         4            105
# 481         0              1
# 482         0              1
# 483         4             54
# dtype: int64
#
#
# Cluster 18 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 261         0           180
#             1             8
# 262         4             1
# 263         4          2246
# 264         0           150
#             1            90
# 265         0             3
#             1             3
# 266         0             1
#             1             1
#             4            30
# 267         0            30
#             4           208
# 268         1            31
# 269         0          1357
#             1          1474
# 270         4           204
# 271         4             1
# 272         4             3
# 273         4             4
# 274         0             8
# 275         0          1938
#             1          4144
# 276         0             1
#             1            27
#             4             3
# 277         0            36
#             1            38
# 278         4            10
# 279         0            30
#             1            77
#             4            85
# 280         0            12
#             1            12
# 281         0            21
# 282         4           743
# 283         1             1
# 284         4           124
# 285         4             2
# 286         4             2
# 287         4             2
# dtype: int64
#
#
# Cluster 19 details:
# Alarm Patterns:
# Alarm Name  Site ID
# 443         2              36
# 444         2               1
# 445         2               8
# 446         1               1
# 447         4              64
# 448         0              14
#             1              75
# 449         3            8161
# 450         4              47
# 452         1               1
#             2              37
#             3               3
# 453         0             342
# 454         0           38284
#             1             927
# 455         0               1
# 456         1               1
# 458         2               7
# 459         0          251677
# 463         0               2
# dtype: int64
#          Site ID  Alarm Name  Vendor  Domain  Device Type  Relative Day Index  \
# 3864387        0         459       0       4           18                   0
# 3864391        4         229       0       2           10                   0
# 3864397        4         230       0       2           22                   0
# 3864406        0         459       0       4           18                   0
# 3864414        1         248       0       4            6                   0
# ...          ...         ...     ...     ...          ...                 ...
# 276            0         459       0       4           18                   0
# 282            4         459       0       2           13                   0
# 280            4         459       0       2           13                   0
# 279            4         459       0       2           13                   0
# 278            4         459       0       2           13                   0
#
#          Cluster
# 3864387       19
# 3864391        4
# 3864397        4
# 3864406       19
# 3864414       12
# ...          ...
# 276           19
# 282            1
# 280            1
# 279            1
# 278            1
#
# [100 rows x 7 columns]

# %%
# Re-scale the dataframe for LSTM
scaler = MinMaxScaler()
df_filtered[['Alarm Name', 'Site ID', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index', 'Cluster']] = scaler.fit_transform(df_filtered[['Alarm Name', 'Site ID', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index', 'Cluster']])

# Prepare the dataset for LSTM
def create_dataset(data, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps)])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 10
features = df_filtered[['Alarm Name', 'Site ID', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index', 'Cluster']].values
X, y = create_dataset(features, time_steps)

# %%
# Reshape input to be [samples, time steps, features]
X = X.reshape(X.shape[0], time_steps, X.shape[2])

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_steps, X.shape[2])))
model.add(LSTM(50))
model.add(Dense(X.shape[2]))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=1, batch_size=2048, verbose=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 779/779 ━━━━━━━━━━━━━━━━━━━━ 159s 200ms/step - loss: 0.0627

# %%
# Predict for the next 7 days (each day has 24 hours)
predictions = []
current_batch = features[-time_steps:].reshape((1, time_steps, X.shape[2]))

for i in range(24 * 7):  # 24 hours * 7 days
    pred = model.predict(current_batch, verbose=0)[0]
    predictions.append(pred)
    current_batch = np.append(current_batch[:, 1:, :], [[pred]], axis=1)

# Inverse transform the predictions
predictions = scaler.inverse_transform(predictions)

# %%
# Create a DataFrame for predictions
relative_day_indices = np.arange(df_filtered['Relative Day Index'].max() + 1, df_filtered['Relative Day Index'].max() + 1 + 24 * 7)
pred_df = pd.DataFrame(predictions, columns=['Alarm Name', 'Site ID', 'Vendor', 'Domain', 'Device Type', 'Relative Day Index', 'Cluster'])
pred_df['Relative Day Index'] = relative_day_indices

# Convert back to original categorical values using label_encoders
for column in label_encoders.keys():
    pred_df[column] = pred_df[column].round().astype(int)
    pred_df[column] = label_encoders[column].inverse_transform(pred_df[column])

# Filter predictions for the next 7 days only
pred_df = pred_df[pred_df['Relative Day Index'] <= 7]

# Display sample output of predictions with cluster details
pred_df.head(7)
# Out:
#                                           Alarm Name Site ID  Vendor Domain  \
# 0                       Power Module Stopped Working  GM0257  HUAWEI   Core
# 1                      Performance Threshold CS CORE  GM0257  HUAWEI   Core
# 2                Performance Threshold Default Alarm  CM2074  HUAWEI   Core
# 3  Performance Measurement Entity Value Exceeds L...  CM2074  HUAWEI   Core
# 4           Peer Entity Capability Is Not Configured  CM2074  HUAWEI   Core
# 5           Peer Entity Capability Is Not Configured  CM2074  HUAWEI   Core
#
#   Device Type  Relative Day Index   Cluster
# 0         UDG                 2.0  4.726676
# 1         UDG                 3.0  5.412091
# 2         UDG                 4.0  5.762794
# 3         UDG                 5.0  5.802648
# 4         UDG                 6.0  5.722408
# 5         UDG                 7.0  5.663376

# %%
# Filter predictions to include only Access domain alarms
pred_df_access = pred_df[pred_df['Domain'] == label_encoders['Domain'].transform(['Access'])[0]]

# Display sample output of Access domain predictions with cluster details
print(pred_df_access.head(7))

# Print the cluster patterns for the predicted alarms
for index, row in pred_df_access.iterrows():
    cluster = int(row['Cluster'])
    print(f"Predicted Alarm for Relative Day Index {row['Relative Day Index']}:")
    print(f"Cluster {cluster} Alarm Patterns:")
    alarm_names = cluster_patterns[cluster].index.get_level_values(0).map(lambda x: label_encoders['Alarm Name'].inverse_transform([x])[0])
    print(pd.Series(cluster_patterns[cluster].values, index=alarm_names))
    print("\n")

# Print cluster-wise alarm patterns
for cluster in range(optimal_clusters):
    print(f"Cluster {cluster} Alarm Patterns:")
    alarm_names = cluster_patterns[cluster].index.get_level_values(0).map(lambda x: label_encoders['Alarm Name'].inverse_transform([x])[0])
    print(pd.Series(cluster_patterns[cluster].values, index=alarm_names))
    print("\n")
# Out:
# Empty DataFrame
# Columns: [Alarm Name, Site ID, Vendor, Domain, Device Type, Relative Day Index, Cluster]
# Index: []
# Cluster 0 Alarm Patterns:
# Alarm Name
# Login Attempts Reach the Maximum Value               1
# Login Attempts Reach the Maximum Value               1
# Loop occurs due to TTL timeout                       2
# Loss of the reference source                        24
# Lost synchronization of a TDM high-speed link        6
# Low Fuel Alarm                                       3
# M2PA Link Fault                                     24
# M2PA Link Fault                                     24
# M2PA SCTP Path Fault                                17
# M2PA SCTP Path Fault                                16
# M2UA Link out of service                             5
# M2UA LinkSet out of service                          3
# M2UA SCTP Path Alarm                                 5
# M3UA Application Server Inaccessible             43856
# M3UA Application Server Inaccessible             43866
# M3UA Destination Entity Inaccessible                10
# M3UA Destination IP Address Inaccessible            28
# M3UA Link Congestion                              4668
# M3UA Link Congestion                              5158
# M3UA Link Fault                                  25614
# M3UA Link Fault                                  24445
# M3UA Link Fault                                     16
# M3UA Link Overload                                  39
# M3UA Linkset Fault                               43854
# M3UA Linkset Fault                               43864
# M3UA Route Unavailable                           43860
# M3UA Route Unavailable                           43873
# M3UA Route Unavailable                              10
# M3UA SCTP Path Alarm                               528
# M3UA SCTP Path Fault                              3018
# M3UA SCTP Path Fault                              3500
# M3UA SCTP path Faulty                              469
# M3UA Signaling Link Failed                          96
# M3UA destination entity is inaccessible           1906
# M3UA destination entity unreachable                135
# M3UA link failure                                   40
# M3UA link fault                                   2319
# M3UA link set failure                               67
# M3UA message flow control                         7274
# dtype: int64
#
#
# Cluster 1 Alarm Patterns:
# Alarm Name
# Remote Address Unreachable               26
# Remote Maintenance Link Failure          33
# Routine test failure of the board        30
# S1 Interface Fault                       37
# S1ap Link Down                       287859
# SCCP DPC Prohibited                      10
# SCCP DPC paused                         787
# SCCP DSP Inaccessible                   902
# SCCP Message Loop                         2
# SCCP SSN Paused                        1370
# dtype: int64
#
#
# Cluster 2 Alarm Patterns:
# Alarm Name
# Board Communication Function Failure                         1
# Board Fault                                                  6
# Board Hardware Fault                                         4
# Board Hardware Fault                                        30
# Board Not In Position                                        1
# Board Port Detection Abnormal                                3
# Board Port Detection Abnormal                                3
# Board Port Fault                                            17
# Board Software Synchronization Failure                       3
# Board Unavailable                                           96
# Board clock abnormality                                    141
# Board deactivation                                         821
# Board fault                                              24906
# Board having faulty semi-permanent connection              747
# Board software abnormality                                 330
# Bond Status Abnormal                                        33
# Bond Status Abnormal                                        74
# C/D interface location update flux over load              1610
# CDR Synchronization is Abnormal                              2
# CP and UP Key Configuration Inconsistent                    30
# CPU MCE/AER error                                            1
# CPU Usages of UVP Key Processes Exceed the Thresholds    53362
# CPU congestion                                               1
# CPU overload                                                 9
# CSL Fault                                                    3
# CSL Fault                                                    9
# CSL Fault                                                   89
# CSLB and VNRS Control Plane Goes Subhealthy                  4
# Capacity Is About to Reach the Threshold                     1
# Capacity Is About to Reach the Threshold                     1
# Card Stopped Working                                         9
# Card Stopped Working                                         1
# Carrier No Traffic                                          15
# Cascading interface failure                                155
# Cascading link connection not matching                       4
# Cell Blocked                                                 2
# Cell Blocked                                               112
# Cell Blocked                                                16
# Cell Capability Degraded                                     1
# Cell Capability Degraded                                    37
# Cell Out of Service                                         16
# Cell Out of Service                                         55
# Cell Out of Service                                        733
# dtype: int64
#
#
# Cluster 3 Alarm Patterns:
# Alarm Name
# Diameter Destination IP Address Inaccessible        49
# Diameter Destination IP Address Inaccessible        70
# Diameter Link Abnormal                             198
# Diameter Link Congestion                           524
# Diameter Link Congestion                           516
# Diameter Link Down                                  34
# Diameter Link Down                                 118
# Diameter Link Failed                               730
# Diameter Link Fault                               2399
# Diameter Link Fault                               2652
# Diameter LinkSet Congestion                        405
# Diameter LinkSet Congestion                        429
# Diameter LinkSet Fault                             402
# Diameter LinkSet Fault                             469
# Diameter Peer Device Congestion                    405
# Diameter Peer Device Congestion                    429
# Diameter Peer Device Fault                         404
# Diameter Peer Device Fault                         469
# Diameter Peer Down                                   6
# Diameter Peer Entity Failed                         51
# Diameter Route Invalid                               2
# Diameter SCTP Path Failure                          14
# Diameter SCTP Path Fault                           207
# Diameter SCTP Path Fault                           219
# Diameter link fault                                 23
# Diameter message route fail                         81
# Diameter message route fail                         69
# Disconnect with Emergency Workstation                1
# Disconnection to the MGC                             8
# Disk Enclosure Is Working In Single Link State       2
# Disk Is About To Fail                                1
# Disk Is About To Fail                                1
# Disk Is Faulty                                       3
# Disk array fails to store CDRs                       2
# Drive status abnormal                                1
# Drive status abnormal                                2
# E1/T1 channel fault                               2549
# ERRORDOWN                                            3
# ERRORDOWN                                           97
# ESL Link Fault                                       3
# ESL Link Fault                                      10
# Error packet on the IPC channel                     26
# Eth-Trunk Member Down                              367
# Eth-Trunk Member Down                              274
# Event Statistic Alarm                               33
# Event Statistic Alarm                               46
# Expansion Port Link Down                             1
# Export Task Export Failed                           66
# dtype: int64
#
#
# Cluster 4 Alarm Patterns:
# Alarm Name
# HTTP Connection Between FusionSphere Neutron and Huawei SDN Controller Is Faulty       17
# Hard disk fault                                                                         1
# Hard disk fault                                                                         1
# Hard disk prewarning                                                                    1
# Heartbeat Between DBS Instances Timed Out                                             206
# Heartbeat Between DBS and Remote DSG Module Timed Out                                  24
# Heartbeat Between DBS and Remote DSG Module Timed Out                                  49
# Host Network Port Fault                                                                80
# Host Network Port Fault                                                               323
# Host Storage Link Failure                                                               9
# Host conflict                                                                         461
# Hugepage Memory Insufficient                                                            1
# I layer CPU Usage Exceeds the Threshold                                                18
# I/O Delay of the Storage Disk Is Too Long                                               6
# IFM Dispatch Unbalance                                                                  2
# IP Address Conflict                                                                     2
# IP Address Conflict                                                                    55
# IP Addresses Conflict                                                                   3
# IP Auto Locate Fault Detect Failure                                                    13
# IP Auto Locate Fault Info                                                            4051
# IP NS-VC Dynamic Negotiation Fault                                                      2
# IP NS-VC Dynamic Negotiation Fault                                                      6
# IP NS-VC Link Fault                                                                  1292
# IP NS-VC Link Fault                                                                  1340
# IP PM Activation Failure                                                               25
# IP PM Activation Failure                                                                4
# IP PM Activation Failure                                                                3
# IP PM Activation Failure                                                               41
# IP Unreachable Alarm                                                                  397
# IP interface failure                                                                   52
# IP path to the gateway unstable                                                       138
# IPPM session fault                                                                  58622
# IPv6 Interface State Change                                                            18
# IPv6 Status of All VPN Interfaces Is Down                                              10
# IUA Link out of service                                                                 8
# IUA LinkSet out of service                                                              3
# IUA SCTP Path Alarm                                                                    10
# Inconsistent NTP Time Between NFs                                                       1
# Incorrect Auto Database Backup Configuration on Third-Party Server                      2
# Incorrect Auto Node Backup Configuration on Third-Party Server                          5
# Incorrect MAC Entries for Backplane Ports of the GE Switching Board                     1
# dtype: int64
#
#
# Cluster 5 Alarm Patterns:
# Alarm Name
# M3UA route is unavailable                                7866
# M3UA route unavailable                                      1
# MAC Address Flapping Alarm                                 42
# MAC Address Flapping Alarm                                 52
# MAC Address Flapping in BD                                  5
# MAC and IP Address Conflict                                 8
# MGW Out of Service                                          8
# MGW overload                                                4
# MME Entity is Inaccessible                                  3
# MTP Communication Fault                                     1
# MTP Communication Fault                                    11
# MTP Destination Signaling Point Inaccessible            38285
# MTP Destination Signaling Point Inaccessible              945
# MTP Link Fault                                             40
# MTP Link Fault                                             24
# MTP Linkset Fault                                           4
# MTP Linkset Fault                                           3
# MTP Route Transmit Disabled                             38580
# MTP Route Transmit Disabled                             41734
# MTP Route Unavailable                                   44376
# MTP Route Unavailable                                   44378
# MTP3 destination signaling point unreachable              362
# MTP3 link failure                                           9
# MTP3 link set failure                                     178
# Mains Failure Alarm                                        10
# Mains Failure Alarm                                        59
# Mains Failure Alarm                                         1
# Master Key Expired                                          2
# Master Key Expired Early                                   26
# Master Key Expired Early                                    1
# Master Key Expired Early                                    4
# Microservice Heartbeat Timed Out                           44
# Minor Alarm Caused by Abnormal Hot Swap Status              2
# Mlag port down                                            278
# Module Fault                                              162
# Module Fault                                              819
# Module Fault                                             3798
# Module Isolation                                           48
# Module Not Ready                                         6512
# Module level decline of KPI entity exceeds threshold       19
# NE Is Disconnected                                         13
# NE Is Disconnected                                         18
# NE Is Disconnected                                         32
# NE Is Disconnected                                         18
# NE Is Disconnected                                        222
# NE License Feature On Trial                                69
# NE Mediation Layer Version Unmatched                        1
# NE Mediation Layer Version Unmatched                        1
# NE Mediation Layer Version Unmatched                        1
# NF HeartBeat Abnormal                                      30
# dtype: int64
#
#
# Cluster 6 Alarm Patterns:
# Alarm Name
# One DNS Server No Response                                                   4
# One DNS Server No Response                                                  10
# One Fabric Link Failed                                                       3
# One high priority BE site existed                                           53
# Online Setting Failure                                                       5
# Online Setting Failure                                                       1
# OpenStack Agent Disconnected                                                24
# Optical Invalid                                                              1
# Optical Module Fault                                                         2
# Optical Module IIC Trap                                                      1
# Optical Module Removed (Base)                                               29
# Optical Removed                                                              7
# Optical Removed                                                             22
# P2P QoS Abnormity                                                         1271
# PDB Power Supply Fault                                                       6
# PDF abnormality                                                             25
# PES Loading Global Data Failed                                               9
# PES Loading Global Data Failed                                               8
# PTP BVC Faulty                                                           13425
# Packet loss ratio on the IP interface reaching threshold                    13
# Patch Activated But Not Confirmed                                          102
# Peer Entity Capability Is Not Configured                                     2
# Peer link of the LACP member interface might be incorrectly connected        6
# Performance Measurement Entity Value Exceeds Level 1 Threshold            2768
# Performance Measurement Entity Value Exceeds Level 1 Threshold            3093
# Performance Measurement Entity Value Exceeds Level 2 Threshold            1741
# Performance Measurement Entity Value Exceeds Level 2 Threshold            1912
# Performance Measurement Entity Value Exceeds Level 2 Threshold            1254
# Performance Measurement Entity Value Exceeds Level 3 Threshold             420
# Performance Measurement Entity Value Exceeds Level 3 Threshold             574
# Performance Measurement Entity Value Exceeds Level 3 Threshold             231
# Performance Measurement Entity Value Exceeds Level 4 Threshold             194
# Performance Measurement Entity Value Exceeds Level 4 Threshold             317
# Performance Measurement Entity Value Exceeds Level 4 Threshold              22
# Performance Threshold CS CORE                                                4
# Performance Threshold CS CORE                                             3737
# Performance Threshold Default Alarm                                        439
# Performance statistics beyond the threshold                                 17
# Physical Entity Entered Master State                                         2
# Physical Entity Failed                                                      11
# Physical Network Unhealthy                                                 189
# Physical Port Down (Entity)                                                 56
# Physical entity failed                                                      35
# dtype: int64
#
#
# Cluster 7 Alarm Patterns:
# Alarm Name
# The OMU Failed to Communicate with the NTP Server            2
# The OMU Failed to Communicate with the NTP Server            3
# The OMU Failed to Communicate with the NTP Server           43
# The OMU Failed to Synchronize Time with the NTP Server       1
# The OMU Failed to Synchronize Time with the NTP Server      12
#                                                           ...
# iGWB-ACM disconnected                                     1208
# linkdown                                                    28
# linkdown                                                   142
# vCPU Core Binding Conflict                                   1
# vHA ETCD Is Not Available                                    1
# Length: 74, dtype: int64
#
#
# Cluster 8 Alarm Patterns:
# Alarm Name
# A Service Instance Is Not Ready                                      11
# ACL resource alarm                                                    1
# ACPI is in the soft-off state                                         1
# ACPI is in the working state                                          2
# ALC Controlling Threshold Crossing                                10294
# ARP Detection Failure                                                 3
# ARP VLAN CAR Enhancement                                             11
# Abnormal Information About DIP Switch of Subrack                      2
# Abnormal NTP Connection Status                                        4
# Abnormal NTP Connection Status                                        1
# Abnormal OMU Resources                                               19
# Abnormality of the configuration of the clock reference source        4
# Absent Power Module                                                   2
# Account Locked                                                        1
# Account Locked                                                       13
# Active Microservice Instance Is Missing                              22
# Address Pool Group Usage Beyond Threshold                            63
# Adjacent Node IP Path Excessive Packet Loss Rate                    142
# Alarm Box Offline                                                    13
# Alarm of eSight                                                     669
# Alarm of eSight                                                    9258
# Alarm of failed LAG negotiation                                     336
# Alarm of failed LAG negotiation                                     301
# All LAG Bandwidth Loss                                              333
# All LAG Bandwidth Loss                                              262
# All Links Between ATS and Peer CCF Disconnected                      28
# All Links Between DIAMRM and peer device Disconnected                13
# Ambient Temperature Unacceptable                                      5
# dtype: int64
#
#
# Cluster 9 Alarm Patterns:
# Alarm Name
# Cell Unavailable                                                                     1
# Cell Unavailable                                                                    18
# Cell Unavailable                                                                    62
# Cell Unavailable                                                                   112
# Cell Unavailable                                                                   208
# CertMgr certificate expired                                                         46
# Comm Fail Between Host and iGWB Server                                              30
# Comm Link Fault Between Host and External Server                                    60
# Communication Between NMS And NE Is Abnormal                                      1479
# Communication Between NMS And NE Is Abnormal                                        47
# Communication Between PaaSBroker and FusionStage Failed                              2
# Communication Between the OMU and the SMM Management Unit Failed                     5
# Communication Between the OpenStack OM and SNMP Management Station Interrupted       2
# Communication Failure Between Modules                                             2841
# Communication Failure Between NE and EMS                                             4
# Communication Failure Between OMU and VNFC                                           2
# Communication Failure Between OMU and VNFM                                           3
# Communication Failure Between OMU and VNFM                                           4
# Communication Failure Between OMU and VNFM                                          62
# Communication Failure Between PCRF and PCEF                                         13
# Communication Failure Between PCRF and PCEF                                         26
# Communication Failure Between PCRF and PCEF                                         54
# Communication Failure Between VNFMAdaptor and VNFM                                  20
# Communication Failure Between VNFMAdaptor and VNFM                                  12
# Communication Failure Between the OMU and Board                                      6
# Communication Failure Between the OMU and Service Management Unit                    2
# Communication Failure Between the OMU and Service Management Unit                   63
# Communication Failure in the OMU HA System                                          11
# Communication Failure of Media Plane                                                 1
# Component Fault                                                                    520
# Component Fault                                                                    154
# Configuration Changed                                                             7698
# Configuration Changed                                                             1296
# Configuration Data Exceeding License Capacity                                        4
# Configuration File Changed                                                         201
# Configuration File Changed                                                         275
# Configuration Inconsistency in TAIs on the MME and eNodeB                            1
# Configurations are not saved                                                         8
# Configured Capacity Limit Exceeding Licensed Limit                                   3
# Configured Capacity Limit Exceeding Licensed Limit                                   1
# Connection Between the DBG and Physical Database Failed                              8
# Connection Between the NDF and Physical Database Failed                              4
# Connection Between the PGW and Physical Database Failed                             60
# dtype: int64
#
#
# Cluster 10 Alarm Patterns:
# Alarm Name
# Annual License Fee Shall Be Due                                           69
# Annual License Fee Unpaid After the Due Date                             213
# Annual License Fee Unpaid After the Due Date                             126
# Annual software service fee expired                                       93
# Attack Defense Packets Discarded                                          20
# BAM to Host Communication Failure                                         16
# BAM to Particular NTPServer Communication Failure                          2
# BBU Board Maintenance Link Failure                                         1
# BBU CPRI Interface Error                                                   2
# BBU CPRI Interface Error                                                 125
# BFD Session Down                                                          48
# BFD Session Down                                                          27
# BFD Session Down                                                          40
# BFD session went Down                                                  13730
# BGP Connection Interrupted                                                29
# BGP Connection Interrupted                                                76
# BGP Connection Interruption                                               62
# BGP Connection Interruption                                               44
# BGP Connection Interruption                                               32
# BGP Status Changed                                                       334
# BGP Status Changed                                                       704
# BGP peer abnormal                                                          6
# BIOS/BootLoader menu password is not set or is the default password        8
# BKP DB Execution Failure                                                1565
# BSC Service Object Configuration Incomplete                                7
# BSS Internal Voice Channel Abnormal                                      272
# Backup Alarm                                                               1
# Backup Failed                                                            848
# Backup Route Abnormal                                                      1
# Base Plane Goes Subhealthy by Pod                                        240
# Base Plane Packet Error and Loss                                           1
# Batched S1ap Link Faults                                                 474
# Battery Deep Discharge Alarm                                              39
# Battery Deep Discharge Alarm                                               1
# Bidirectional forwarding detection abnormal                               25
# Board Active-Standby Abnormal                                              1
# dtype: int64
#
#
# Cluster 11 Alarm Patterns:
# Alarm Name
# STP Discarded Error Messages by the Self PC Alarm                                      13
# STP Discarded Error Messages by the Self PC Alarm                                       9
# Security Hardening Is Not Made                                                          4
# Security Hardening Is Not Made                                                          8
# Service Center and Service Communication Failure                                       12
# Service Center and Service Communication Failure                                      153
# Service Console Process of BAM Server Stopped                                           2
# Service Filter Rule Not Effective                                                      10
# Service Frame Report State To  Control Frame Fail                                      16
# Service Module Overload                                                                 1
# Service Node Resources Not Sufficient                                                  22
# Service Not Ready                                                                      11
# Service filter rule is not effective                                                   29
# Severe bit error of the TDM switching network board                                   104
# Signal deterioration of E1/T1 channels                                              17599
# Signaling packet length exceeds limitation                                             47
# Signalling path disconnected                                                          174
# Single Plane of BAM to Host Connection Failure                                         32
# Slow Disk Response                                                                      1
# Software Parameter Inconsistency In Location                                            9
# Software parameter modification not take effect                                         5
# Some Functions of Power Module Were Invalid                                             5
# Some Functions on the Chassis Were Invalid                                              4
# Statistical Alarm                                                                    2439
# Stopped Receiving CDRs                                                                 24
# Storage Device Drive Fault                                                              2
# Subscribers Fail to be Migrated                                                         1
# Subscription and Support Service Has Expired                                            1
# Switch to the backup IP route                                                          23
# Switchover Between Active and Standby Nodes                                             1
# System Backup Failed                                                                   17
# System Backup Failed                                                                  217
# System Dynamic Traffic Exceeding Licensed Limit                                        37
# System Dynamic Traffic Exceeding Licensed Limit                                        81
# System Flowctrl Startup                                                                 1
# System Used Resource will overrun the threshold of Connection Admission Control        59
# System Used Resource will overrun the threshold of Connection Admission Control        67
# TDM high-speed link abnormal                                                          179
# TRX Manually Blocked                                                                   17
# Temperature Alarm                                                                       1
# Temperature alarm on a board hardware module                                            4
# The Billing System Has Not Fetched CDR Files for a Long Time                          113
# The DFS peer status changed to Down                                                     7
# The DSG remote config is inconsistent                                                   8
# The DSG remote config is timeout                                                        4
# The DSG remote config is timeout                                                        4
# The DSG remote config is timeout                                                       60
# The GSN Does not Respond to the vCG                                                    82
# The Hard Disk Is Isolated                                                               2
# The Hard Disk Is Isolated                                                               2
# The License Is About To Expire                                                          3
# The Number of Current Alarms Reaches the Threshold                                      1
# dtype: int64
#
#
# Cluster 12 Alarm Patterns:
# Alarm Name
# Indicates that insecure protocols or algorithms is enabled                                       1
# Insecure Configuration Exist                                                                     9
# Insecure Configuration Exist                                                                    31
# Insecure Configuration Is Enabled                                                                8
# Insecure Configuration Is Enabled                                                               85
# Insecure Configuration Is Enabled On Board                                                     372
# Insecure Protocols Or Algorithms Is Enabled                                                      9
# Insecure encryption Algorithm Or Protocol                                                        4
# Insufficient Disk Space for User Plane Northbound Feature                                     3196
# Insufficient Disk Space for User Plane Northbound Feature                                     3216
# Insufficient Disk Space for User Plane Northbound Feature (Major)                              143
# Insufficient Disk Space for User Plane Northbound Feature (Minor)                              149
# Inter-Location DSG Module Heartbeat Timed Out                                                   30
# Inter-Location DSG Module Heartbeat Timed Out                                                   28
# Inter-Location DSG Module Heartbeat Timed Out                                                12055
# Inter-MME Access Flow Control                                                                   92
# Inter-MME Access Flow Control                                                                  676
# Interface Down                                                                                  57
# Interface Down                                                                                  12
# Interface Down                                                                                  72
# Interface IE Inconsistent                                                                        1
# Interface IP Address Conflict                                                                    1
# Interface IP Address Conflict                                                                    2
# Interface IPv6 status changed                                                                  126
# Interface IPv6 status changed                                                                   46
# Irregular power at NIC optical module major alarm                                                9
# Irregular power at NIC optical module major alarm                                              124
# KPI Change Exceeding Threshold                                                                  43
# KPI Change Exceeding Threshold                                                                 392
# Key System Resource Usage Exceeding Threshold                                                    1
# L2UA link failure                                                                               12
# L2UA link set failure                                                                            5
# dtype: int64
#
#
# Cluster 13 Alarm Patterns:
# Alarm Name
# NF_Registration_Failed                                                                                   1
# NG-RAN Link Fault                                                                                        1
# NSVL Dynamic Configuration Procedure Failure                                                             7
# NTP Failed To Synchronize Time                                                                           2
# NTP Server Failed to Connect to the External Clock Source or the External Clock Source Failed            1
# NTP connection failed                                                                                   30
# NTP service abnormal                                                                                     2
# NTP service abnormal                                                                                     7
# Negotiation Failure Due to Packet Changes on Member Links                                               13
# Network Subhealth                                                                                       21
# New NETCONF Server Session                                                                              16
# No Available NS-VC in NSE                                                                              666
# No Available NS-VC in NSE                                                                               45
# No License Running in System                                                                             1
# No response from the PCRF                                                                               13
# No response from the RADIUS accounting server                                                          470
# No response from the RADIUS accounting server                                                          826
# No response from the RADIUS authentication server                                                       30
# No response from the RADIUS authentication server                                                        2
# Node Communication Failure                                                                               4
# Node Heartbeat Timed Out                                                                               306
# Northbound File Is Not Generated                                                                        58
# Northbound File Transfer Is Slow                                                                     15043
# Northbound Service Does Not Consume Kafka Data                                                         151
# Number of Measurement Objects Reaches or Exceeds Maximum Specification                                2963
# Number of Resources Will Exceed License Limit                                                           10
# Number of Subscribers Approaching the Threshold Specified by the License                                 4
# Number of Subscribers Reached the Threshold Specified by the License                                     2
# Number of key drop cause count on the NP Chip increases abruptly and exceeds the preset threshold        2
# Number of occpuy circuits exceeding threshold                                                            4
# Number of office's fault circuits exceed threshold                                                      41
# Number of trunk group's fault circuits exceed threshold                                                670
# OML Fault                                                                                                3
# OML Fault                                                                                               10
# OMU Board Fault                                                                                          1
# OMU Configuration Board and Subrack Board Inconsistency                                                  4
# OSPF Generated New LSA                                                                                  52
# OSPF Interface State Changed                                                                            32
# OSPF Interface State Changed                                                                           585
# OSPF LSA Will Age Out                                                                                  287
# OSPF Neighbor Down                                                                                       4
# OSPF Neighbor State Changed                                                                             16
# OSPF Neighbor State Changed                                                                            341
# OSPFv3 Neighbor State Changed                                                                           24
# dtype: int64
#
#
# Cluster 14 Alarm Patterns:
# Alarm Name
# External Clock Reference Problem                                       1
# External Clock Reference Problem                                      27
# FTP/SFTP File Transfer Failure                                       258
# FTP/SFTP Link Failure                                                 17
# Fabric Link Goes Subhealthy                                            1
# Fabric Port Communication Goes Subhealthy                              2
# Failed RAID array detected                                             2
# Failed To Monitor A Disk Enclosure                                     2
# Failed to Send Remote Notifications                                    5
# Failure of a TDM cascading optical interface                          58
# Fan frame abnormality                                                  1
# Fault in the FE cascading network interface                           35
# Faulty Host                                                          143
# Faulty Host                                                           94
# Faulty RabbitMQ Service                                                3
# Faulty Transmission Channel on a Port                                624
# Faulty VM Directory File                                               1
# Faulty VM Directory File                                               3
# Faulty VM OS                                                         122
# Faulty VM OS                                                          92
# File Stack for User Plane Northbound Feature                         158
# File Upload Failure for User Plane Northbound Feature               3485
# Flow Control of User Data Query                                        3
# Format Engine Package Is Abnormal                                      1
# Forward Resources Reached Upper Threshold                              4
# Forwarding packets in Rx. and Tx. direction unbalanced                68
# Free Storage Space Insufficient                                        2
# Frequency offset of the master reference source beyond the scope       2
# Fuse Failure Alarm                                                     2
# Fuse Failure Alarm                                                    16
# GE channel fault                                                      23
# GSM Cell Manually Blocked                                             11
# GSM KPI Exceed Threshold                                             392
# GSM Local Cell Capability Decline                                      4
# GSM Local Cell Capability Decline                                      1
# GSM Local Cell Unusable                                                1
# GSM Local Cell Unusable                                                2
# GTP Path Fault                                                        11
# GTPC Tunnel Path Broken                                               41
# Gateway Detect Failure                                                20
# Gateway Detect Failure                                                 4
# Gateway resolution failed                                             58
# Generator On Load Alarm                                                5
# Global E1 Ports Are Blocked                                            1
# Global traffic task entity result exceeds threshold                  132
# H.248 SCTP Path Alarm                                                259
# H.248 SCTP link failure                                              135
# H.248 signaling link fault                                             1
# H.248 signaling link fault                                           766
# H248(SCTP) Static Link path fault                                     16
# H248(SCTP) Static Link path fault                                     16
# HAProxy Backend Services Fault                                        10
# HAProxy Backend Services Fault                                         2
# dtype: int64
#
#
# Cluster 15 Alarm Patterns:
# Alarm Name
# Connection Between the SPG and NE Failed                                         3
# Cpu Overloaded(level 1)                                                         14
# Crc error alarm notification                                                    13
# DBS SCTP Link Fault                                                            145
# DBS SCTP Link Fault                                                            335
# DFS Dual-Active Detection Message Loss                                           8
# DHCP Service Is Unavailable                                                     28
# DIMM MCE error                                                                   1
# DLB SCTP Link Congestion                                                         1
# DLB SCTP Path Failure                                                           21
# DLB SCTP Path Failure                                                           54
# DNS Link Down                                                                   24
# DNS Link Down                                                                   36
# DPDK LACP Bond Failed                                                           21
# DPDK LACP Bond Failed                                                          173
# DRA not reachable                                                               56
# DSG Link-related Configurations Are Inconsistent                                 6
# DSG SCTP Link Fault                                                            385
# DSG SCTP Link Fault                                                            387
# DSG SCTP Link Fault                                                          20898
# DSG SCTP Path Failure                                                          440
# DSG SCTP Path Failure                                                          413
# DSG SCTP Path Failure                                                         8525
# Data Inconsistency                                                               4
# Data Store Usage Exceeds the Threshold                                           3
# Data Store Usage Exceeds the Threshold                                          10
# Data Store Virtual Capacity Usage Exceeds the Threshold                          3
# Data Store Virtual Capacity Usage Exceeds the Threshold                          3
# Data Synchronization Failure Between the Active and Standby OMU Databases       11
# Data path disconnected                                                          12
# Data path disconnected                                                          12
# Data recovery of the GE channel clock failed                                    16
# Database Backup or Restoration Failed                                           25
# Decline of KPI Entity Exceeds Threshold                                          2
# Decline of KPI Entity Exceeds Threshold                                          1
# Decline of KPI Entity Exceeds Threshold                                          3
# Decline of KPI entity exceeds threshold                                         12
# Detected RU Base Plane Goes Subhealthy                                           2
# dtype: int64
#
#
# Cluster 16 Alarm Patterns:
# Alarm Name
# Physical manage interface down                                                             1
# Ping                                                                                      84
# Plug-in Package Versions or Redundancy Switch Settings of Two Sites Are Inconsistent      12
# Port Fault of LAN Switch                                                                   8
# Port-based CPCAR Automatic Attack Defense                                                252
# Port-based CPCAR Automatic Attack Defense                                                142
# Power Module Has No Input                                                                  1
# Power Module Not Powered On                                                                2
# Power Module Stopped Working                                                               5
# Power Module Stopped Working                                                               2
# Power supply abnormal                                                                      2
# Process Fault                                                                              7
# Process Fault                                                                            138
# RAID Fault                                                                                 1
# RAID Fault                                                                                17
# RAN IP/ATM Bearer Status Fault                                                          8593
# RF Out of Service                                                                       3646
# RF Unit AC Input Power Failure                                                            30
# RF Unit CPRI Interface Error                                                             180
# RF Unit DC Input Power Failure                                                            75
# RF Unit DC Input Power Failure                                                             2
# RF Unit DC Input Power Failure                                                             1
# RF Unit Hardware Fault                                                                     5
# RF Unit Hardware Fault                                                                     3
# RF Unit Maintenance Link Failure                                                           6
# RF Unit Maintenance Link Failure                                                         415
# RF Unit Maintenance Link Failure                                                           4
# RF Unit Maintenance Link Failure                                                           1
# RF Unit TX Channel Gain Out of Range                                                       1
# RF Unit TX Channel Gain Out of Range                                                       2
# RF Unit Temperature Unacceptable                                                           1
# RF Unit VSWR Threshold Crossed                                                             7
# RFC RF Port Input Power Out of Range                                                      21
# RHUB CPRI Interface Error                                                                188
# RHUB Optical Module or Electrical Port Not Ready                                          23
# RHUB Unit AC Input Power Failure                                                         250
# RHUB-pRRU CPRI Interface Error                                                           570
# RRU Cascading Levels and Configuration Mismatch                                            1
# RRU Cascading Levels and Configuration Mismatch                                           51
# RU Fault Alarm                                                                             8
# RU Fault Alarm                                                                             2
# RU Fault Alarm                                                                            39
# dtype: int64
#
#
# Cluster 17 Alarm Patterns:
# Alarm Name
# SCCP SSN paused                                                     958
# SCCP Subsystem Fault                                                 10
# SCCP Subsystem Fault                                                  7
# SCCP Subsystem Prohibited                                             2
# SCCP status is inconsistent between DCU module and SSU modules       59
# SCCP status is inconsistent between DCU module and SSU modules        1
# SCTP Link Congestion                                                  1
# SCTP Link Congestion                                                  7
# SCTP Link Congestion                                               8375
# SCTP Link Fault                                                       9
# SCTP Link Fault                                                       4
# SCTP Link Fault                                                   22696
# SCTP Link IP Address Unreachable                                     30
# SCTP Packet Error Rate Too High                                       1
# SCTP Path Failure                                                   643
# SCTP association retransmission above the threshold                 232
# SCTP path failure                                                  1379
# SDH/STM-1 HP fault                                                  186
# SDH/STM-1 path fault                                               1966
# SGS SCTP Link Fault                                                  12
# SGsAP Destination IP Address Inaccessible                             4
# SGsAP Destination IP Address Inaccessible                             8
# SIP office heart beat is fault                                      105
# SNMP Connection Failure                                               1
# SNMP connect failed                                                   1
# STC Out of Service                                                   54
# dtype: int64
#
#
# Cluster 18 Alarm Patterns:
# Alarm Name
# L3VPN VRF Down                                                             180
# L3VPN VRF Down                                                               8
# LACP Negotiation Between Member Ports of the Eth-trunk Interface Fails       1
# LAI(GCI or SAI) at BSC(RNC) is inconsistent with MSC                      2246
# License Control Item Is About to Expire                                    150
# License Control Item Is About to Expire                                     90
# License Feature Expired                                                      3
# License Feature Expired                                                      3
# License File Expired                                                         1
# License File Expired                                                         1
# License File Expired                                                        30
# License File Expiring Precaution                                            30
# License File Expiring Precaution                                           208
# License Is About to Enter Grace Period                                      31
# Link Bear Quality                                                         1357
# Link Bear Quality                                                         1474
# Link Between ATS and Peer CCF Disconnected                                 204
# Link Between BCF and DRA Disconnected                                        1
# Link Between I-CSCF and DRA Disconnected                                     3
# Link Between S-CSCF and DRA Disconnected                                     4
# Link Between UIM and Peer Diameter Entity Failed                             8
# Link Down                                                                 1938
# Link Down                                                                 4144
# Link Failure Between PCRF and Diameter Peer                                  1
# Link Failure Between PCRF and Diameter Peer                                 27
# Link Failure Between PCRF and Diameter Peer                                  3
# Link Failure Between PCRF and Notification Server                           36
# Link Failure Between PCRF and Notification Server                           38
# Link Failure Between PCRF and Notification server                           10
# Link Failure Between PCRF and PCEF                                          30
# Link Failure Between PCRF and PCEF                                          77
# Link Failure Between PCRF and PCEF                                          85
# Link Failure Between PCRF and Redundancy PCRF                               12
# Link Failure Between PCRF and Redundancy PCRF                               12
# Link Plane Fault                                                            21
# Link Used by the DSG Is Inconsistent with That Configured                  743
# Link bandwidth lost totally                                                  1
# Links for Uploading EDRs Are Faulty or EDR Uploading Fails                 124
# Loading Failed                                                               2
# Loading Global Data Failed                                                   2
# Locational channel data inconsistent                                         2
# dtype: int64
#
#
# Cluster 19 Alarm Patterns:
# Alarm Name
# Radio Link Failure                                     36
# Radio Link Failure                                      1
# Radio Signaling Link Disconnected                       8
# Rate of packets to cpu exceeded the CPCAR limit         1
# Realm not reachable                                    64
# Receive Signal Loss                                    14
# Receive Signal Loss                                    75
# Rectifier Failure Alarm                              8161
# Redundancy Failed                                      47
# Remote Maintenance Link Failure                         1
# Remote Maintenance Link Failure                        37
# Remote Maintenance Link Failure                         3
# Remote Neighbor Status Changed                        342
# Remote SCCP Fault                                   38284
# Remote SCCP Fault                                     927
# Remote Synchronization Fail                             1
# Resources Were Exhausted                                1
# S1 Interface Fault                                      7
# S1ap Link Down                                     251677
# SCCP Message Loop                                       2
# dtype: int64

# %%
# Display sample output of predictions with cluster details
print(pred_df_access.head(7))
# Out:
# Empty DataFrame
# Columns: [Alarm Name, Site ID, Vendor, Domain, Device Type, Relative Day Index, Cluster]
# Index: []
